# %% [markdown]
# # UQPINNs
#
# Satisfying the PDE constraint by simply minimizing the mean square loss on collocation points.
# \begin{align}
#     \mathcal{L}_{PDE}(\theta) = \frac{1}{N_r}\sum_{i=1}^{N_r}\|r_{\theta}(x_i, t_i)\|^2.
# \end{align}
# with
# \begin{align}
# 	\mathcal{L}_{\mathcal{D}}(\psi) = & \  \mathbb{E}_{q(x,t)p(z)}[\log\sigma(T_{\psi}(x,t,f_{\theta}(x,t,z)))] + \\ & \ \mathbb{E}_{q(x,t,u)}[\log(1-\sigma(T_{\psi}(x,t,u)))],\\
# 	\mathcal{L}_{\mathcal{G}}(\theta, \phi) = & \ \mathbb{E}_{q(x,t)p(z)}[T_{\psi}(x, t, f_{\theta}(x,t,z))\\
# 	&+ (1-\lambda)\log(q_{\phi}(z|x,t,f_{\theta}(x,t,z)))],
# \end{align}
# Then, the resulting adversarial game for training the physics-informed model:
# \begin{align}
#     & \mathop{\max}_{\psi} \ \mathcal{L}_{\mathcal{D}}(\psi)\\
#     & \mathop{\min}_{\theta, \phi} \ \mathcal{L}_{\mathcal{G}}(\theta, \phi) + \mathcal{L}_{PDE}(\theta),
# \end{align}

# %%
# Define the model class

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import timeit

# Model class takes the intput:
# X_f: collocation points in [-1, 1], X_u: positions on the boundary (in this case -1 and 1), 
# Y_u: data on the boundary (in this case, boundary conditions), layers_P: network structure of generator,
# layers_Q: network structure of encoder, layers_T: network structure of discriminator,
# lam: entropic regularization coefficient, beta: physics-informed regularization

class ODE_UQPINN:
    # Initialize the class
    def __init__(self, X_f, X_u, Y_u, layers_P, layers_Q, layers_T, lam = 1.0, beta = 1.0): 
        # X_f: collocation points, X_u: input data X, Y_u: output data Y,
        # layers_P: decoder network structure, layers_Q: encoder network structure, layers_T: discriminator network structure,
        # lam: entropic regularization parameter, beta: physics-informed regularization parameter
                
        # Normalize data
        self.Xmean = X_f.mean(0)
        self.Xstd = X_f.std(0)
        self.Ymean = Y_u.mean(0)
        self.Ystd = Y_u.std(0)
        X_f = (X_f - self.Xmean) / self.Xstd
        X_u = (X_u - self.Xmean) / self.Xstd
        # Jacobian with respect to the normalization
        self.Jacobian = 1 / self.Xstd
        
        # Normalized and collocation points and training input, output data
        self.X_f = X_f
        self.X_u = X_u
        self.Y_u = Y_u
        
        # Neural network structures
        self.layers_P = layers_P
        self.layers_Q = layers_Q
        self.layers_T = layers_T
        
        # Input, output and latent variable dimensions
        self.X_dim = X_u.shape[1]
        self.Y_dim = Y_u.shape[1]
        self.Z_dim = layers_Q[-1]
        
        # Regularization parameters
        self.lam = lam
        self.beta = beta

        # # material property
        # self.E = E
        # self.I = I
        
        # Ratio of training for generator and discriminator in each iteration: k1 for discriminator, k2 for generator
        self.k1 = 1
        self.k2 = 5

        # Initialize network weights and biases        
        self.weights_P, self.biases_P = self.initialize_NN(layers_P)
        self.weights_Q, self.biases_Q = self.initialize_NN(layers_Q)
        self.weights_T, self.biases_T = self.initialize_NN(layers_T)
        
        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
        
        # Define placeholders and computational graph
        self.X_u_tf = tf.placeholder(tf.float32, shape=(None, self.X_dim))
        self.X_f_tf = tf.placeholder(tf.float32, shape=(None, self.X_dim))
        self.Y_u_tf = tf.placeholder(tf.float32, shape=(None, self.Y_dim))
        self.Z_u_tf = tf.placeholder(tf.float32, shape=(None, self.Z_dim))
        self.Z_f_tf = tf.placeholder(tf.float32, shape=(None, self.Z_dim))

        # Predict output
        self.Y_u_pred = self.net_P(self.X_u_tf, self.Z_u_tf)
        # Predict the residual at collocation points
        self.Y_f_pred = self.get_r(self.X_f_tf, self.Z_f_tf)

        # Generator loss (to be minimized)
        self.G_loss, self.KL_loss, self.recon_loss, self.PDE_loss  = self.compute_generator_loss(self.X_u_tf, self.Y_u_tf, self.Y_u_pred,
                                                                        self.X_f_tf, self.Y_f_pred, self.Z_u_tf, self.Z_f_tf)
                                                
        # Discriminator loss (to be minimized)
        self.T_loss  = self.compute_discriminator_loss(self.X_u_tf, self.Y_u_tf, self.Z_u_tf)
        
        # Generate samples of y given x by sampling from latent space
        self.sample = self.sample_generator(self.X_u_tf, self.Z_u_tf)

        # Define optimizer        
        self.optimizer_KL = tf.train.AdamOptimizer(1e-4)
        self.optimizer_T = tf.train.AdamOptimizer(1e-4)
        
        # Define train Ops
        self.train_op_KL = self.optimizer_KL.minimize(self.G_loss, 
                                                      var_list = [self.weights_P, self.biases_P,
                                                                  self.weights_Q, self.biases_Q])
                                                                    
        self.train_op_T = self.optimizer_T.minimize(self.T_loss,
                                                    var_list = [self.weights_T, self.biases_T])

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    
    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):      
        # Xavier initialization
        def xavier_init(size):
            in_dim = size[0]
            out_dim = size[1]
            xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
            return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev, dtype=tf.float32)   
        
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
           
           
    # Evaluates the forward pass
    def forward_pass(self, H, layers, weights, biases):
        num_layers = len(layers)
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H
    
    # Forcing term (right hand of the ODE)
    def f(self, X_normalized): #
        X = self.Xstd * X_normalized + self.Xmean
        return 5*X
    
    # Decoder: p(y|x,z)
    def net_P(self, X, Z):
        Y = self.forward_pass(tf.concat([X, Z], 1),
                              self.layers_P,
                              self.weights_P,
                              self.biases_P)
        return Y
    
    # Encoder: q(z|x,y)
    def net_Q(self, X, Y):
        Z = self.forward_pass(tf.concat([X, Y], 1),
                              self.layers_Q,
                              self.weights_Q,
                              self.biases_Q)
        return Z
    
    # Discriminator
    def net_T(self, X, Y):
        T = self.forward_pass(tf.concat([X, Y], 1),
                              self.layers_T,
                              self.weights_T,
                              self.biases_T)        
        return T
    
    # Physics-Informed neural network prediction
    def get_u(self, X, Z):
        z_prior = Z       
        u = self.net_P(X, z_prior)
        return u

    # Physics-Informed residual on the collocation points
    def get_r(self, X, Z):
        z_prior = Z    
        u = self.net_P(X, z_prior)
        u_x = tf.gradients(u, X)[0]
        u_xx = tf.gradients(u_x, X)[0]
        f = self.f(X)
        r = (self.Jacobian ** 2) * u_xx + f
        return r    
    
    # Compute the generator loss
    def compute_generator_loss(self, X_u, Y_u, Y_u_pred, X_f, Y_f_pred, Z_u, Z_f):  
        # Prior: z_u for input data, z_f for collocation points
        z_u_prior = Z_u
        z_f_prior = Z_f
        # Encoder: q(z|x,y)
        z_u_encoder = self.net_Q(X_u, Y_u_pred)
        z_f_encoder = self.net_Q(X_f, Y_f_pred)
        # Discriminator loss
        Y_pred = self.net_P(X_u, Z_u)
        T_pred = self.net_T(X_u, Y_pred)
        
        # KL-divergence between the data distribution and the model distribution
        KL = tf.reduce_mean(T_pred)

        # Entropic regularization
        log_q = - tf.reduce_mean(tf.square(z_u_prior-z_u_encoder))
        
        # Physics-informed loss
        loss_f = tf.reduce_mean(tf.square(Y_f_pred))

        # Generator loss
        loss = KL + (1.0-self.lam)*log_q + self.beta * loss_f
        
        return loss, KL, (1.0-self.lam)*log_q, self.beta * loss_f
    
    # Compute the discriminator loss
    def compute_discriminator_loss(self, X, Y, Z): 
        # Prior: p(z)
        z_prior = Z
        # Decoder: p(y|x,z)
        Y_pred = self.net_P(X, z_prior)                
        
        # Discriminator loss
        T_real = self.net_T(X, Y)
        T_fake = self.net_T(X, Y_pred)
        
        T_real = tf.sigmoid(T_real)
        T_fake = tf.sigmoid(T_fake)
        
        T_loss = -tf.reduce_mean(tf.log(1.0 - T_real + 1e-8) + \
                                 tf.log(T_fake + 1e-8)) 
        
        return T_loss
           
    
    # Fetches a mini-batch of data
    def fetch_minibatch(self,X, Y, N_batch):
        N = X.shape[0]
        idx = np.random.choice(N, N_batch, replace=False)
        X_batch = X[idx,:]
        Y_batch = Y[idx,:]
        return X_batch, Y_batch
    
    
    # Trains the model
    def train(self, nIter = 20000, N_u = 2, N_f = 100): 

        start_time = timeit.default_timer()
        for it in range(nIter):     

            # Sampling from the latent space for data and collocation points
            Z_u = np.random.randn(N_u, self.Z_dim)
            Z_f = np.random.randn(N_f, self.Z_dim)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.X_u_tf: self.X_u, self.Y_u_tf: self.Y_u, self.X_f_tf: self.X_f,
                     self.Z_u_tf: Z_u, self.Z_f_tf: Z_f}  
            
            # Run the Tensorflow session to minimize the loss
            for i in range(self.k1):
                self.sess.run(self.train_op_T, tf_dict)
            for j in range(self.k2):
                self.sess.run(self.train_op_KL, tf_dict)
        
            # Print
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_KL_value, reconv, loss_PDE = self.sess.run([self.KL_loss, self.recon_loss, self.PDE_loss], tf_dict)
                loss_T_value = self.sess.run(self.T_loss, tf_dict)
                print('It: %d, KL_loss: %.2e, Recon_loss: %.2e, PDE_loss: %.2e, T_loss: %.2e, Time: %.2f' % 
                      (it, loss_KL_value, reconv, loss_PDE, loss_T_value, elapsed))
                start_time = timeit.default_timer()
                
    # Generate samples of y given x by sampling from the latent space z
    def sample_generator(self, X, Z):        
        # Prior:
        z_prior = Z       
        # Decoder: p(y|x,z)
        Y_pred = self.net_P(X, z_prior)      
        return Y_pred

    # Predict y given x
    def generate_sample(self, X_star):
        # Normalize the input data
        X_star = (X_star - self.Xmean) / self.Xstd
        Z = np.random.randn(X_star.shape[0], self.Z_dim)
        tf_dict = {self.X_u_tf: X_star, self.Z_u_tf: Z}       
        Y_star = self.sess.run(self.sample, tf_dict) 
        Y_star = Y_star 
        return Y_star
# Out:
# 2024-12-10 14:19:32.923020: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-10 14:19:32.923245: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-10 14:19:32.925444: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-10 14:19:32.955628: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-10 14:19:33.425630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/ayadav4/.local/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Implementation

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import numpy as np
import matplotlib.pyplot as plt

import scipy.io
from plotting import newfig, savefig
import time
from scipy import stats

np.random.seed(1234)

# %%
print(tf.__version__)
# Out:
# 2.16.1

# %%
# Number of collocation points
N_f = 200

# Number of testing points
N_ref = 200

# Number of the training data (in this example on the boundary)
N_u = 20

# Define the input, output, latent variable dimension
X_dim = 1
Y_dim = 1
Z_dim = 1


# material property
E = 2e7
I = 1e-6
# Uncertainty in boundary condition
mu_eta = 0.0; # Mean of uncertainty in boundary condition
sigma_eta = 0.000005 # Standard deviation of uncertainty

# Reference solution
def f(X,E,I):
    return -(50/(3*E*I))* X**3

# Position of the collocation points
X_f = np.linspace(0.,1.,N_f)[:,None]

# Position of the boundary conditions

# X_ut = np.linspace(0.,1.,3)[:,None]

# Correcting the concatenate function
X_ut = np.linspace(0.,1.,2)[:,None]
X_u = X_ut
for i in range(N_u-1):
    X_u = np.vstack((X_u, X_ut))

print(np.size(X_u))

# Generate stochastic boundary condition
np.random.seed(42)  # Set random seed for reproducibility
eta_samples = np.random.normal(mu_eta, sigma_eta, 1)  # Sample E from normal distribution

Y_ut = f(X_ut,E,I) - eta_samples
Y_u = Y_ut
for i in range(N_u-1):
    eta_samples = np.random.normal(mu_eta, sigma_eta, 1)  # Sample E from normal distribution
    Y_ut = f(X_ut,E,I) - eta_samples
    Y_u = np.vstack((Y_u, Y_ut))

print(np.size(Y_u))

# Reference solution on the testing points
X_ref = np.linspace(0.,1.,N_ref)[:,None]
Y_ref = f(X_ref,E,I)

# # Load the reference solution of the stochastic ODE generated by Monte Carlo
# data = scipy.io.loadmat('./ODE2000.mat')
# Exact = np.real(data['U']).T


# # Define noise level
# noise_level = 0.05





# # Position of the collocation points
# X_f = np.linspace(0.,1.,N_f)[:,None]

# # Position of the boundary conditions
# # Monte Carlo sampling
# np.random.seed(42)  # Set random seed for reproducibility
# E_samples = np.random.normal(E, sigma_E, N_u)  # Sample E from normal distribution

# X_ut = np.linspace(0.,1.,N_f)[:,None]
# X_u = X_ut
# for i in range(N_u-1):
#     X_u = np.vstack((X_u, X_ut))

# print(np.size(X_u))


# # Compute deflection for each sample of E
# Y_u = np.array([f(X_ut, E, I) for E in E_samples])

# print(np.size(Y_u))

# # Generate stochastic boundary condition
# # Y_ut = f(X_ut)
# # Y_u = Y_ut
# # for i in range(N_u-1):
# #     Y_ut = noise_level * np.random.randn(2, Y_dim)
# #     Y_u = np.vstack((Y_u, Y_ut))

# # Reference solution on the testing points
# X_ref = np.linspace(0.,1.,N_ref)[:,None]
# Y_ref = f(X_ref,E,I)

# # # Load the reference solution of the stochastic ODE generated by Monte Carlo
# # data = scipy.io.loadmat('./ODE1000.mat')
# # Exact = np.real(data['w_samples']).T
# Out:
# 40
# 40

# %%
# Model creation
layers_P = np.array([X_dim+Z_dim,50,50,50,50,Y_dim])
layers_Q = np.array([X_dim+Y_dim,50,50,50,50,Z_dim])
layers_T = np.array([X_dim+Y_dim,50,50,1])

# Define the model
model = ODE_UQPINN(X_f, X_u, Y_u, layers_P, layers_Q, layers_T, lam = 1.5, beta = 1.)
# Out:
# Device mapping: no known devices.
# 2024-12-10 14:19:34.487426: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-10 14:19:34.487736: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_1/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_2/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_2: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_3/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_3/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_3: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_3: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_4/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_4/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_4: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_4: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_8/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_9/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_5/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_5/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_5: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_5: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_10/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_11/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_6/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_6/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_6: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_6: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_12/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_13/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_7/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_7/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_7: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_7: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_14/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_15: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_15/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_15/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_8/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_8/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_8: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_8: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_16/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_17/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_9/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_9/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_9: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_9: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_18/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_19/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_10/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_10/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_10: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_10: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_20/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_21: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_21/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_21/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_11/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_11/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_11: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_11: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_22/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_23/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_12/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_12/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# random_normal_12: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_12: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_24/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# Variable_25/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_1: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_2: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_2: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_2: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_3: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_3: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_3: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_4: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_4: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_1: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_5: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_5: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_4: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_6: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_6: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_5: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_7: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_7: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_6: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_8: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_8: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_7: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_9: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_9: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_9_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_9_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_9_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_9_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_9_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Tanh_7_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_8_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_8_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_8_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_8_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_8_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Tanh_6_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_7_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_7_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_7_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_7_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_7_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Tanh_5_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_6_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_6_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_6_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_6_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_6_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Tanh_4_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_5_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_5_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/Add_5_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_5_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/MatMul_5_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/concat_1_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/concat_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/concat_1_grad/ShapeN: (ShapeN): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/concat_1_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/concat_1_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# gradients/concat_1_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/stack: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/concat_1_grad/Slice_grad/Pad: (Pad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_5_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_5_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_6_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_6_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_5_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_5_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_5_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_5_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_7_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_7_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_6_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_6_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_6_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_6_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_8_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/MatMul_8_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_7_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_7_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_7_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/gradients/Tanh_7_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Tanh_7_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_8_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_8_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_8_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_8_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_8_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/AddN: (AddN): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Tanh_6_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_7_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_7_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_7_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_7_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_7_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/AddN_1: (AddN): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Tanh_5_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_6_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_6_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_6_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_6_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_6_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/AddN_2: (AddN): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Tanh_4_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_5_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_5_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/Add_5_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_5_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/MatMul_5_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/concat_1_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/concat_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/concat_1_grad/ShapeN: (ShapeN): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/concat_1_grad/ConcatOffset: (ConcatOffset): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/concat_1_grad/Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_1/concat_1_grad/Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# mul_13: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# add_10: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_14: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# mul_15: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# add_11: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_2: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_10: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_12: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_8: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_11: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_13: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_9: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_12: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_14: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_10: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_13: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_15: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_11: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_14: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_16: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_3: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_15: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_17: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_12: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_16: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_18: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_13: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_17: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_19: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_14: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_18: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_20: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_15: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_19: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_21: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_4: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_20: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_22: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_16: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_21: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_23: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_17: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_22: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_24: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_18: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_23: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_25: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_19: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_24: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_26: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_5: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_25: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_27: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_20: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_26: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_28: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_21: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_27: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_29: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Mean: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# Square: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# Mean_1: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# Square_1: (Square): /job:localhost/replica:0/task:0/device:CPU:0
# Mean_2: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# mul_16: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# add_30: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_17: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# add_31: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# mul_18: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# mul_19: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# concat_6: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_28: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_32: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_22: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_29: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_33: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_23: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_30: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_34: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_24: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_31: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_35: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_25: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_32: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_36: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_7: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_33: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_37: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_26: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_34: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_38: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_27: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_35: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_39: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# concat_8: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_36: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_40: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_28: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_37: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_41: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_29: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_38: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_42: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# Sigmoid_1: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# add_43: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Log: (Log): /job:localhost/replica:0/task:0/device:CPU:0
# add_44: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Log_1: (Log): /job:localhost/replica:0/task:0/device:CPU:0
# add_45: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Mean_3: (Mean): /job:localhost/replica:0/task:0/device:CPU:0
# Neg_1: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# concat_9: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_39: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_46: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_30: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_40: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_47: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_31: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_41: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_48: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_32: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_42: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_49: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# Tanh_33: (Tanh): /job:localhost/replica:0/task:0/device:CPU:0
# MatMul_43: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# Add_50: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/grad_ys_0: (Fill): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_31_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_31_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_31_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_30_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_30_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_30_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_17_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_17_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_17_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_17_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_17_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_16_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_16_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_16_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_16_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_16_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_2_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_29_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_29_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_29_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_29_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_29_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_29_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Neg_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Square_1_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Square_1_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_27_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_27_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_27_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_27_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_27_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/Tile: (Tile): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/Prod: (Prod): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/Cast: (Cast): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Mean_1_grad/truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/add_11_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Tanh_21_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Square_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Square_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/mul_15_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_28_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_28_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_28_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_28_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_28_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_28_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Neg: (Neg): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/sub_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/stack: (Pack): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/concat: (ConcatV2): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/concat_1_grad/Slice_grad/Pad: (Pad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_26_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_26_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_26_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_26_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_26_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_16_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_16_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_16_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_16_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_16_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_16_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_5_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_5_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_5_grad/MatMul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_5_grad/MatMul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_5_grad/MatMul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Tanh_20_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_14_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_14_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_14_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_14_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_14_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/mul_2: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Tanh_4_grad/TanhGrad_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_27_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_27_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_27_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_27_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_27_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_27_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Tanh_11_grad/TanhGrad: (TanhGrad): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/AddN_2_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/AddN_2_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/AddN_2_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_25_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_25_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_25_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_25_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/MatMul_25_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_15_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_15_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_15_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_15_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_15_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/Add_15_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Shape: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Shape_1: (Shape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/BroadcastGradientArgs: (BroadcastGradientArgs): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Sum: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Sum_1: (Sum): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/Reshape_1: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/gradients/Tanh_4_grad/TanhGrad_grad/mul_2_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_6_grad/MatMul_grad/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_6_grad/MatMul_grad/MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_6_grad/MatMul_grad/tuple/group_deps: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_6_grad/MatMul_grad/tuple/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/MatMul_6_grad/MatMul_grad/tuple/control_dependency_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/concat_5_grad/mod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# ...
# 2024-12-10 14:19:34.939312: I tensorflow/core/common_runtime/placer.cc:125] Variable_2/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939314: I tensorflow/core/common_runtime/placer.cc:125] Variable_4/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939316: I tensorflow/core/common_runtime/placer.cc:125] Variable_4/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939318: I tensorflow/core/common_runtime/placer.cc:125] Variable_4/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939320: I tensorflow/core/common_runtime/placer.cc:125] Variable_4/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939322: I tensorflow/core/common_runtime/placer.cc:125] Variable_6/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939323: I tensorflow/core/common_runtime/placer.cc:125] Variable_6/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939325: I tensorflow/core/common_runtime/placer.cc:125] Variable_6/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939327: I tensorflow/core/common_runtime/placer.cc:125] Variable_6/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939329: I tensorflow/core/common_runtime/placer.cc:125] Variable_8/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939331: I tensorflow/core/common_runtime/placer.cc:125] Variable_8/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939334: I tensorflow/core/common_runtime/placer.cc:125] Variable_1/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939336: I tensorflow/core/common_runtime/placer.cc:125] Variable_1/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939338: I tensorflow/core/common_runtime/placer.cc:125] Variable_3/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939339: I tensorflow/core/common_runtime/placer.cc:125] Variable_3/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939347: I tensorflow/core/common_runtime/placer.cc:125] Variable_5/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939350: I tensorflow/core/common_runtime/placer.cc:125] Variable_5/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939352: I tensorflow/core/common_runtime/placer.cc:125] Variable_7/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939354: I tensorflow/core/common_runtime/placer.cc:125] Variable_7/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939356: I tensorflow/core/common_runtime/placer.cc:125] Variable_9/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939358: I tensorflow/core/common_runtime/placer.cc:125] Variable_9/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939360: I tensorflow/core/common_runtime/placer.cc:125] Variable_10/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939362: I tensorflow/core/common_runtime/placer.cc:125] Variable_10/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939364: I tensorflow/core/common_runtime/placer.cc:125] Variable_12/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939366: I tensorflow/core/common_runtime/placer.cc:125] Variable_12/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939369: I tensorflow/core/common_runtime/placer.cc:125] Variable_12/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939371: I tensorflow/core/common_runtime/placer.cc:125] Variable_12/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939373: I tensorflow/core/common_runtime/placer.cc:125] Variable_14/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939375: I tensorflow/core/common_runtime/placer.cc:125] Variable_14/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939377: I tensorflow/core/common_runtime/placer.cc:125] Variable_14/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939379: I tensorflow/core/common_runtime/placer.cc:125] Variable_14/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939381: I tensorflow/core/common_runtime/placer.cc:125] Variable_16/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939383: I tensorflow/core/common_runtime/placer.cc:125] Variable_16/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939385: I tensorflow/core/common_runtime/placer.cc:125] Variable_16/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939387: I tensorflow/core/common_runtime/placer.cc:125] Variable_16/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939389: I tensorflow/core/common_runtime/placer.cc:125] Variable_18/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939391: I tensorflow/core/common_runtime/placer.cc:125] Variable_18/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939393: I tensorflow/core/common_runtime/placer.cc:125] Variable_11/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939395: I tensorflow/core/common_runtime/placer.cc:125] Variable_11/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939397: I tensorflow/core/common_runtime/placer.cc:125] Variable_13/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939399: I tensorflow/core/common_runtime/placer.cc:125] Variable_13/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939401: I tensorflow/core/common_runtime/placer.cc:125] Variable_15/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939403: I tensorflow/core/common_runtime/placer.cc:125] Variable_15/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939405: I tensorflow/core/common_runtime/placer.cc:125] Variable_17/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939407: I tensorflow/core/common_runtime/placer.cc:125] Variable_17/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939409: I tensorflow/core/common_runtime/placer.cc:125] Variable_19/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939411: I tensorflow/core/common_runtime/placer.cc:125] Variable_19/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939414: I tensorflow/core/common_runtime/placer.cc:125] Adam/learning_rate: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939417: I tensorflow/core/common_runtime/placer.cc:125] Adam/beta1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939419: I tensorflow/core/common_runtime/placer.cc:125] Adam/beta2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939421: I tensorflow/core/common_runtime/placer.cc:125] Adam/epsilon: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939424: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939426: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/grad_ys_0/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939428: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Mean_3_grad/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939431: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Mean_3_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939433: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Mean_3_grad/GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939435: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Mean_3_grad/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939438: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/add_43_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939440: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/add_43_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939442: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/add_44_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939444: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/add_44_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939447: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/sub_1_grad/Shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939449: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/sub_1_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939451: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_42_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939453: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_42_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939456: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_39_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939458: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_39_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939460: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_41_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939463: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_41_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939465: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_38_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939468: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_38_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939470: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_40_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939473: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_40_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939475: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_37_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939477: I tensorflow/core/common_runtime/placer.cc:125] gradients_3/Add_37_grad/Sum/reduction_indices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939479: I tensorflow/core/common_runtime/placer.cc:125] beta1_power_1/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939482: I tensorflow/core/common_runtime/placer.cc:125] beta2_power_1/initial_value: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939484: I tensorflow/core/common_runtime/placer.cc:125] Variable_20/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939486: I tensorflow/core/common_runtime/placer.cc:125] Variable_20/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939488: I tensorflow/core/common_runtime/placer.cc:125] Variable_22/Adam/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939490: I tensorflow/core/common_runtime/placer.cc:125] Variable_22/Adam/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939492: I tensorflow/core/common_runtime/placer.cc:125] Variable_22/Adam_1/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939494: I tensorflow/core/common_runtime/placer.cc:125] Variable_22/Adam_1/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939496: I tensorflow/core/common_runtime/placer.cc:125] Variable_24/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939498: I tensorflow/core/common_runtime/placer.cc:125] Variable_24/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939500: I tensorflow/core/common_runtime/placer.cc:125] Variable_21/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939502: I tensorflow/core/common_runtime/placer.cc:125] Variable_21/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939504: I tensorflow/core/common_runtime/placer.cc:125] Variable_23/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939505: I tensorflow/core/common_runtime/placer.cc:125] Variable_23/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939507: I tensorflow/core/common_runtime/placer.cc:125] Variable_25/Adam/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939509: I tensorflow/core/common_runtime/placer.cc:125] Variable_25/Adam_1/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939512: I tensorflow/core/common_runtime/placer.cc:125] Adam_1/learning_rate: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939514: I tensorflow/core/common_runtime/placer.cc:125] Adam_1/beta1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939516: I tensorflow/core/common_runtime/placer.cc:125] Adam_1/beta2: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2024-12-10 14:19:34.939518: I tensorflow/core/common_runtime/placer.cc:125] Adam_1/epsilon: (Const): /job:localhost/replica:0/task:0/device:CPU:0

# %%
# Train the model
model.train(nIter = 30000, N_u = 2*N_u, N_f = N_f)
# Out:
# It: 0, KL_loss: -5.42e-05, Recon_loss: 4.64e-01, PDE_loss: 1.02e+01, T_loss: 1.39e+00, Time: 0.25
# It: 100, KL_loss: 3.35e-01, Recon_loss: 3.86e-01, PDE_loss: 2.36e-01, T_loss: 1.21e+00, Time: 1.62
# It: 200, KL_loss: -1.33e-01, Recon_loss: 1.28e-02, PDE_loss: 9.07e-02, T_loss: 1.41e+00, Time: 1.63
# It: 300, KL_loss: 1.89e-01, Recon_loss: 7.47e-03, PDE_loss: 3.72e-02, T_loss: 1.31e+00, Time: 1.51
# It: 400, KL_loss: 3.34e-02, Recon_loss: 3.81e-03, PDE_loss: 1.06e-02, T_loss: 1.30e+00, Time: 1.66
# It: 500, KL_loss: -1.56e-02, Recon_loss: 5.31e-03, PDE_loss: 5.24e-02, T_loss: 1.34e+00, Time: 1.53
# It: 600, KL_loss: -5.12e-02, Recon_loss: 3.61e-03, PDE_loss: 1.81e-02, T_loss: 1.40e+00, Time: 1.44
# It: 700, KL_loss: 1.13e-02, Recon_loss: 8.91e-04, PDE_loss: 3.86e-03, T_loss: 1.39e+00, Time: 1.04
# It: 800, KL_loss: -2.26e-02, Recon_loss: 2.49e-04, PDE_loss: 2.06e-03, T_loss: 1.39e+00, Time: 0.94
# It: 900, KL_loss: 8.23e-04, Recon_loss: 1.00e-04, PDE_loss: 1.44e-03, T_loss: 1.39e+00, Time: 1.14
# It: 1000, KL_loss: 5.63e-03, Recon_loss: 1.17e-04, PDE_loss: 1.91e-03, T_loss: 1.39e+00, Time: 1.09
# It: 1100, KL_loss: -7.30e-04, Recon_loss: 4.56e-05, PDE_loss: 1.13e-03, T_loss: 1.39e+00, Time: 1.44
# It: 1200, KL_loss: -1.32e-03, Recon_loss: 2.79e-04, PDE_loss: 8.44e-04, T_loss: 1.39e+00, Time: 1.12
# It: 1300, KL_loss: 4.55e-04, Recon_loss: 4.69e-05, PDE_loss: 7.26e-04, T_loss: 1.39e+00, Time: 1.05
# It: 1400, KL_loss: 1.46e-03, Recon_loss: 9.92e-05, PDE_loss: 4.00e-04, T_loss: 1.39e+00, Time: 1.11
# It: 1500, KL_loss: -1.46e-03, Recon_loss: 1.58e-04, PDE_loss: 4.32e-04, T_loss: 1.39e+00, Time: 1.17
# It: 1600, KL_loss: -1.75e-03, Recon_loss: 4.34e-05, PDE_loss: 4.61e-04, T_loss: 1.39e+00, Time: 1.34
# It: 1700, KL_loss: 1.82e-03, Recon_loss: 5.16e-05, PDE_loss: 3.07e-04, T_loss: 1.39e+00, Time: 1.08
# It: 1800, KL_loss: -2.06e-03, Recon_loss: 3.27e-05, PDE_loss: 2.89e-04, T_loss: 1.39e+00, Time: 1.30
# It: 1900, KL_loss: 3.01e-03, Recon_loss: 7.89e-05, PDE_loss: 3.63e-04, T_loss: 1.39e+00, Time: 1.37
# It: 2000, KL_loss: 6.49e-03, Recon_loss: 5.80e-04, PDE_loss: 4.10e-04, T_loss: 1.39e+00, Time: 1.48
# It: 2100, KL_loss: 5.29e-03, Recon_loss: 7.26e-05, PDE_loss: 2.89e-04, T_loss: 1.39e+00, Time: 1.23
# It: 2200, KL_loss: 3.40e-03, Recon_loss: 6.69e-05, PDE_loss: 3.84e-04, T_loss: 1.39e+00, Time: 1.23
# It: 2300, KL_loss: -3.88e-03, Recon_loss: 9.67e-05, PDE_loss: 3.45e-04, T_loss: 1.39e+00, Time: 0.91
# It: 2400, KL_loss: -5.04e-03, Recon_loss: 9.15e-05, PDE_loss: 1.90e-04, T_loss: 1.39e+00, Time: 1.42
# It: 2500, KL_loss: 2.64e-03, Recon_loss: 3.88e-04, PDE_loss: 5.43e-04, T_loss: 1.39e+00, Time: 1.45
# It: 2600, KL_loss: -9.31e-04, Recon_loss: 3.09e-05, PDE_loss: 3.25e-04, T_loss: 1.39e+00, Time: 1.13
# It: 2700, KL_loss: -4.99e-03, Recon_loss: 1.78e-05, PDE_loss: 4.18e-04, T_loss: 1.39e+00, Time: 1.52
# It: 2800, KL_loss: -4.19e-03, Recon_loss: 1.77e-04, PDE_loss: 3.20e-04, T_loss: 1.39e+00, Time: 1.74
# It: 2900, KL_loss: -1.87e-03, Recon_loss: 3.20e-03, PDE_loss: 3.34e-04, T_loss: 1.39e+00, Time: 1.50
# It: 3000, KL_loss: -1.52e-03, Recon_loss: 3.29e-05, PDE_loss: 1.75e-04, T_loss: 1.39e+00, Time: 1.44
# It: 3100, KL_loss: -9.09e-04, Recon_loss: 3.50e-04, PDE_loss: 3.95e-04, T_loss: 1.39e+00, Time: 1.23
# It: 3200, KL_loss: 5.24e-03, Recon_loss: 9.45e-06, PDE_loss: 1.47e-04, T_loss: 1.39e+00, Time: 1.57
# It: 3300, KL_loss: 4.46e-03, Recon_loss: 3.55e-04, PDE_loss: 2.03e-04, T_loss: 1.39e+00, Time: 1.61
# It: 3400, KL_loss: 4.20e-03, Recon_loss: 2.28e-04, PDE_loss: 2.90e-04, T_loss: 1.39e+00, Time: 1.53
# It: 3500, KL_loss: 5.94e-03, Recon_loss: 1.32e-03, PDE_loss: 4.44e-04, T_loss: 1.39e+00, Time: 1.26
# It: 3600, KL_loss: 4.24e-03, Recon_loss: 2.07e-05, PDE_loss: 4.96e-04, T_loss: 1.39e+00, Time: 1.11
# It: 3700, KL_loss: -4.13e-03, Recon_loss: 8.60e-05, PDE_loss: 4.39e-04, T_loss: 1.39e+00, Time: 1.23
# It: 3800, KL_loss: -1.04e-02, Recon_loss: 1.41e-05, PDE_loss: 2.91e-04, T_loss: 1.39e+00, Time: 1.41
# It: 3900, KL_loss: -2.25e-02, Recon_loss: 2.39e-05, PDE_loss: 1.52e-04, T_loss: 1.39e+00, Time: 1.43
# It: 4000, KL_loss: -2.40e-02, Recon_loss: 1.68e-05, PDE_loss: 1.95e-04, T_loss: 1.39e+00, Time: 1.23
# It: 4100, KL_loss: -2.07e-02, Recon_loss: 2.09e-04, PDE_loss: 3.72e-04, T_loss: 1.39e+00, Time: 1.73
# It: 4200, KL_loss: 4.81e-04, Recon_loss: 4.17e-03, PDE_loss: 3.88e-04, T_loss: 1.39e+00, Time: 1.82
# It: 4300, KL_loss: 3.77e-02, Recon_loss: 1.47e-05, PDE_loss: 2.37e-04, T_loss: 1.39e+00, Time: 1.91
# It: 4400, KL_loss: 2.22e-02, Recon_loss: 3.73e-03, PDE_loss: 3.35e-04, T_loss: 1.39e+00, Time: 1.98
# It: 4500, KL_loss: -5.75e-03, Recon_loss: 2.05e-05, PDE_loss: 2.35e-04, T_loss: 1.39e+00, Time: 1.87
# It: 4600, KL_loss: -1.81e-02, Recon_loss: 1.29e-02, PDE_loss: 5.05e-04, T_loss: 1.39e+00, Time: 1.80
# It: 4700, KL_loss: -1.29e-02, Recon_loss: 1.79e-04, PDE_loss: 2.14e-04, T_loss: 1.39e+00, Time: 1.06
# It: 4800, KL_loss: -6.86e-03, Recon_loss: 1.18e-04, PDE_loss: 1.02e-04, T_loss: 1.39e+00, Time: 1.45
# It: 4900, KL_loss: 3.36e-03, Recon_loss: 1.76e-05, PDE_loss: 1.89e-04, T_loss: 1.39e+00, Time: 1.43
# It: 5000, KL_loss: 1.54e-03, Recon_loss: 2.72e-05, PDE_loss: 1.01e-04, T_loss: 1.39e+00, Time: 1.45
# It: 5100, KL_loss: -2.46e-03, Recon_loss: 8.77e-05, PDE_loss: 1.57e-04, T_loss: 1.39e+00, Time: 1.43
# It: 5200, KL_loss: 7.24e-03, Recon_loss: 1.11e-03, PDE_loss: 1.51e-04, T_loss: 1.39e+00, Time: 1.60
# It: 5300, KL_loss: 7.88e-03, Recon_loss: 2.00e-05, PDE_loss: 2.87e-04, T_loss: 1.39e+00, Time: 1.46
# It: 5400, KL_loss: 9.85e-03, Recon_loss: 9.95e-06, PDE_loss: 3.54e-04, T_loss: 1.39e+00, Time: 1.44
# It: 5500, KL_loss: 1.17e-02, Recon_loss: 7.48e-05, PDE_loss: 1.68e-04, T_loss: 1.39e+00, Time: 1.46
# It: 5600, KL_loss: 5.10e-03, Recon_loss: 2.12e-04, PDE_loss: 2.14e-04, T_loss: 1.39e+00, Time: 1.37
# It: 5700, KL_loss: 9.72e-03, Recon_loss: 8.23e-04, PDE_loss: 1.01e-04, T_loss: 1.39e+00, Time: 1.50
# It: 5800, KL_loss: 9.78e-03, Recon_loss: 1.04e-05, PDE_loss: 1.91e-04, T_loss: 1.39e+00, Time: 1.50
# It: 5900, KL_loss: 1.72e-02, Recon_loss: 1.20e-04, PDE_loss: 7.91e-05, T_loss: 1.39e+00, Time: 1.49
# It: 6000, KL_loss: 1.66e-02, Recon_loss: 2.69e-05, PDE_loss: 8.45e-05, T_loss: 1.39e+00, Time: 1.48
# It: 6100, KL_loss: 1.94e-02, Recon_loss: 9.53e-06, PDE_loss: 2.85e-04, T_loss: 1.39e+00, Time: 1.44
# It: 6200, KL_loss: 1.67e-02, Recon_loss: 8.68e-04, PDE_loss: 1.32e-04, T_loss: 1.39e+00, Time: 1.47
# It: 6300, KL_loss: 1.59e-02, Recon_loss: 6.84e-06, PDE_loss: 1.01e-04, T_loss: 1.39e+00, Time: 1.36
# It: 6400, KL_loss: 1.75e-02, Recon_loss: 5.57e-05, PDE_loss: 1.97e-04, T_loss: 1.39e+00, Time: 1.32
# It: 6500, KL_loss: 1.57e-02, Recon_loss: 1.35e-05, PDE_loss: 8.58e-05, T_loss: 1.39e+00, Time: 1.39
# It: 6600, KL_loss: 6.52e-03, Recon_loss: 5.23e-04, PDE_loss: 9.58e-05, T_loss: 1.39e+00, Time: 1.45
# It: 6700, KL_loss: 1.62e-02, Recon_loss: 1.22e-03, PDE_loss: 2.41e-04, T_loss: 1.39e+00, Time: 1.27
# It: 6800, KL_loss: 2.05e-03, Recon_loss: 1.18e-05, PDE_loss: 6.39e-05, T_loss: 1.39e+00, Time: 1.34
# It: 6900, KL_loss: 5.70e-03, Recon_loss: 9.16e-05, PDE_loss: 1.09e-04, T_loss: 1.39e+00, Time: 1.43
# It: 7000, KL_loss: 3.09e-03, Recon_loss: 2.40e-05, PDE_loss: 6.96e-05, T_loss: 1.39e+00, Time: 1.51
# It: 7100, KL_loss: 5.28e-03, Recon_loss: 1.92e-05, PDE_loss: 7.09e-05, T_loss: 1.39e+00, Time: 1.54
# It: 7200, KL_loss: -1.05e-02, Recon_loss: 1.24e-04, PDE_loss: 1.12e-04, T_loss: 1.39e+00, Time: 1.41
# It: 7300, KL_loss: -1.04e-02, Recon_loss: 1.83e-04, PDE_loss: 1.25e-04, T_loss: 1.39e+00, Time: 1.46
# It: 7400, KL_loss: -1.74e-02, Recon_loss: 5.48e-05, PDE_loss: 1.17e-04, T_loss: 1.39e+00, Time: 1.56
# It: 7500, KL_loss: -1.88e-02, Recon_loss: 2.89e-05, PDE_loss: 2.42e-04, T_loss: 1.39e+00, Time: 1.43
# It: 7600, KL_loss: -5.53e-03, Recon_loss: 5.32e-05, PDE_loss: 9.29e-05, T_loss: 1.39e+00, Time: 1.50
# It: 7700, KL_loss: -7.38e-03, Recon_loss: 8.07e-05, PDE_loss: 1.27e-04, T_loss: 1.39e+00, Time: 1.47
# It: 7800, KL_loss: -4.98e-03, Recon_loss: 2.12e-05, PDE_loss: 1.27e-04, T_loss: 1.39e+00, Time: 1.59
# It: 7900, KL_loss: -1.07e-02, Recon_loss: 2.52e-04, PDE_loss: 1.06e-04, T_loss: 1.39e+00, Time: 1.53
# It: 8000, KL_loss: -1.06e-02, Recon_loss: 1.06e-05, PDE_loss: 1.56e-04, T_loss: 1.39e+00, Time: 1.33
# It: 8100, KL_loss: -2.03e-02, Recon_loss: 5.45e-05, PDE_loss: 2.71e-04, T_loss: 1.39e+00, Time: 1.56
# It: 8200, KL_loss: -1.11e-02, Recon_loss: 1.99e-05, PDE_loss: 9.19e-05, T_loss: 1.39e+00, Time: 1.50
# It: 8300, KL_loss: -1.80e-02, Recon_loss: 1.54e-05, PDE_loss: 8.18e-05, T_loss: 1.39e+00, Time: 1.53
# It: 8400, KL_loss: -1.83e-02, Recon_loss: 1.38e-03, PDE_loss: 1.40e-04, T_loss: 1.39e+00, Time: 1.35
# It: 8500, KL_loss: -2.26e-02, Recon_loss: 4.73e-05, PDE_loss: 1.16e-04, T_loss: 1.39e+00, Time: 1.54
# It: 8600, KL_loss: -1.54e-02, Recon_loss: 8.72e-05, PDE_loss: 1.89e-04, T_loss: 1.39e+00, Time: 1.59
# It: 8700, KL_loss: -9.33e-03, Recon_loss: 1.90e-05, PDE_loss: 8.22e-05, T_loss: 1.39e+00, Time: 1.48
# It: 8800, KL_loss: -1.77e-04, Recon_loss: 1.35e-03, PDE_loss: 1.33e-04, T_loss: 1.39e+00, Time: 1.68
# It: 8900, KL_loss: 1.73e-03, Recon_loss: 4.44e-05, PDE_loss: 1.16e-04, T_loss: 1.39e+00, Time: 1.21
# It: 9000, KL_loss: -2.68e-03, Recon_loss: 2.72e-05, PDE_loss: 8.22e-05, T_loss: 1.39e+00, Time: 1.37
# It: 9100, KL_loss: 1.57e-03, Recon_loss: 9.95e-05, PDE_loss: 6.69e-05, T_loss: 1.39e+00, Time: 1.42
# It: 9200, KL_loss: -2.26e-03, Recon_loss: 1.58e-05, PDE_loss: 8.21e-05, T_loss: 1.39e+00, Time: 1.47
# It: 9300, KL_loss: -4.94e-03, Recon_loss: 7.08e-04, PDE_loss: 1.25e-04, T_loss: 1.39e+00, Time: 1.50
# It: 9400, KL_loss: 7.85e-03, Recon_loss: 6.89e-04, PDE_loss: 2.14e-04, T_loss: 1.39e+00, Time: 1.51
# It: 9500, KL_loss: 3.26e-03, Recon_loss: 2.32e-05, PDE_loss: 1.14e-04, T_loss: 1.39e+00, Time: 1.46
# It: 9600, KL_loss: 5.26e-03, Recon_loss: 2.44e-05, PDE_loss: 9.42e-05, T_loss: 1.39e+00, Time: 1.45
# It: 9700, KL_loss: 4.99e-03, Recon_loss: 2.56e-02, PDE_loss: 5.47e-04, T_loss: 1.39e+00, Time: 1.58
# It: 9800, KL_loss: -1.85e-03, Recon_loss: 2.32e-04, PDE_loss: 8.32e-05, T_loss: 1.39e+00, Time: 1.64
# It: 9900, KL_loss: -1.37e-02, Recon_loss: 2.57e-05, PDE_loss: 1.09e-04, T_loss: 1.39e+00, Time: 1.71
# It: 10000, KL_loss: -1.76e-02, Recon_loss: 6.24e-04, PDE_loss: 1.38e-04, T_loss: 1.39e+00, Time: 1.72
# It: 10100, KL_loss: -1.51e-02, Recon_loss: 3.67e-03, PDE_loss: 1.75e-04, T_loss: 1.39e+00, Time: 1.73
# It: 10200, KL_loss: -2.30e-02, Recon_loss: 4.51e-05, PDE_loss: 7.84e-05, T_loss: 1.39e+00, Time: 1.26
# It: 10300, KL_loss: -9.20e-03, Recon_loss: 2.69e-05, PDE_loss: 1.65e-04, T_loss: 1.38e+00, Time: 1.18
# It: 10400, KL_loss: -1.31e-02, Recon_loss: 1.93e-05, PDE_loss: 6.59e-05, T_loss: 1.39e+00, Time: 1.19
# It: 10500, KL_loss: -2.92e-03, Recon_loss: 2.40e-05, PDE_loss: 8.58e-05, T_loss: 1.39e+00, Time: 1.31
# It: 10600, KL_loss: -2.88e-03, Recon_loss: 5.23e-03, PDE_loss: 1.39e-04, T_loss: 1.39e+00, Time: 1.36
# It: 10700, KL_loss: -8.01e-04, Recon_loss: 1.14e-04, PDE_loss: 9.95e-05, T_loss: 1.39e+00, Time: 1.58
# It: 10800, KL_loss: 3.55e-03, Recon_loss: 4.08e-04, PDE_loss: 2.10e-04, T_loss: 1.39e+00, Time: 1.52
# It: 10900, KL_loss: -1.06e-05, Recon_loss: 2.82e-04, PDE_loss: 6.76e-05, T_loss: 1.39e+00, Time: 1.31
# It: 11000, KL_loss: 2.80e-03, Recon_loss: 4.33e-05, PDE_loss: 5.30e-05, T_loss: 1.39e+00, Time: 1.01
# It: 11100, KL_loss: -6.68e-03, Recon_loss: 7.69e-04, PDE_loss: 6.04e-05, T_loss: 1.39e+00, Time: 1.16
# It: 11200, KL_loss: -1.57e-03, Recon_loss: 9.43e-06, PDE_loss: 1.76e-04, T_loss: 1.39e+00, Time: 1.22
# It: 11300, KL_loss: 6.83e-03, Recon_loss: 1.97e-02, PDE_loss: 2.61e-04, T_loss: 1.39e+00, Time: 1.55
# It: 11400, KL_loss: -4.67e-03, Recon_loss: 4.72e-03, PDE_loss: 1.05e-04, T_loss: 1.39e+00, Time: 1.48
# It: 11500, KL_loss: -6.43e-03, Recon_loss: 3.29e-05, PDE_loss: 1.00e-04, T_loss: 1.39e+00, Time: 1.32
# It: 11600, KL_loss: -1.58e-02, Recon_loss: 1.88e-05, PDE_loss: 8.79e-05, T_loss: 1.39e+00, Time: 1.63
# It: 11700, KL_loss: -1.32e-02, Recon_loss: 1.06e-05, PDE_loss: 1.33e-04, T_loss: 1.39e+00, Time: 1.58
# It: 11800, KL_loss: -4.17e-03, Recon_loss: 2.32e-04, PDE_loss: 7.91e-05, T_loss: 1.39e+00, Time: 1.51
# It: 11900, KL_loss: -1.09e-02, Recon_loss: 8.23e-06, PDE_loss: 8.14e-05, T_loss: 1.39e+00, Time: 1.43
# It: 12000, KL_loss: -1.57e-02, Recon_loss: 1.94e-05, PDE_loss: 2.47e-04, T_loss: 1.39e+00, Time: 1.60
# It: 12100, KL_loss: -4.78e-03, Recon_loss: 9.77e-05, PDE_loss: 1.01e-04, T_loss: 1.39e+00, Time: 1.47
# It: 12200, KL_loss: -5.66e-03, Recon_loss: 2.19e-04, PDE_loss: 6.86e-05, T_loss: 1.39e+00, Time: 1.44
# It: 12300, KL_loss: -7.60e-03, Recon_loss: 2.93e-05, PDE_loss: 6.33e-05, T_loss: 1.39e+00, Time: 1.56
# It: 12400, KL_loss: 2.12e-03, Recon_loss: 4.20e-03, PDE_loss: 1.28e-04, T_loss: 1.39e+00, Time: 1.56
# It: 12500, KL_loss: 6.69e-04, Recon_loss: 3.27e-05, PDE_loss: 1.22e-04, T_loss: 1.39e+00, Time: 1.35
# It: 12600, KL_loss: -1.09e-02, Recon_loss: 5.78e-05, PDE_loss: 8.77e-05, T_loss: 1.39e+00, Time: 1.46
# It: 12700, KL_loss: -8.46e-03, Recon_loss: 8.65e-06, PDE_loss: 7.31e-05, T_loss: 1.39e+00, Time: 1.48
# It: 12800, KL_loss: -2.23e-02, Recon_loss: 5.08e-05, PDE_loss: 9.11e-05, T_loss: 1.39e+00, Time: 1.46
# It: 12900, KL_loss: -2.53e-02, Recon_loss: 6.82e-04, PDE_loss: 1.15e-04, T_loss: 1.39e+00, Time: 1.53
# It: 13000, KL_loss: -1.49e-02, Recon_loss: 3.47e-03, PDE_loss: 1.20e-04, T_loss: 1.39e+00, Time: 1.07
# It: 13100, KL_loss: -7.14e-03, Recon_loss: 9.36e-03, PDE_loss: 1.40e-04, T_loss: 1.39e+00, Time: 1.55
# It: 13200, KL_loss: -3.60e-03, Recon_loss: 2.63e-04, PDE_loss: 9.27e-05, T_loss: 1.38e+00, Time: 1.20
# It: 13300, KL_loss: -3.47e-03, Recon_loss: 3.24e-05, PDE_loss: 1.31e-04, T_loss: 1.39e+00, Time: 1.54
# It: 13400, KL_loss: -1.19e-02, Recon_loss: 1.27e-05, PDE_loss: 3.68e-04, T_loss: 1.39e+00, Time: 1.42
# It: 13500, KL_loss: -4.14e-03, Recon_loss: 1.63e-05, PDE_loss: 1.12e-04, T_loss: 1.39e+00, Time: 1.18
# It: 13600, KL_loss: -1.36e-03, Recon_loss: 6.13e-04, PDE_loss: 1.34e-04, T_loss: 1.39e+00, Time: 1.45
# It: 13700, KL_loss: -6.64e-03, Recon_loss: 9.34e-05, PDE_loss: 1.20e-04, T_loss: 1.39e+00, Time: 1.42
# It: 13800, KL_loss: -6.09e-03, Recon_loss: 9.15e-04, PDE_loss: 7.17e-04, T_loss: 1.38e+00, Time: 1.39
# It: 13900, KL_loss: -5.37e-03, Recon_loss: 1.34e-04, PDE_loss: 1.97e-04, T_loss: 1.39e+00, Time: 1.49
# It: 14000, KL_loss: 5.38e-03, Recon_loss: 3.63e-05, PDE_loss: 3.14e-04, T_loss: 1.39e+00, Time: 1.41
# It: 14100, KL_loss: 1.38e-02, Recon_loss: 7.12e-05, PDE_loss: 9.17e-05, T_loss: 1.39e+00, Time: 1.43
# It: 14200, KL_loss: 1.41e-02, Recon_loss: 2.49e-04, PDE_loss: 6.90e-05, T_loss: 1.38e+00, Time: 1.45
# It: 14300, KL_loss: 1.42e-03, Recon_loss: 4.45e-04, PDE_loss: 7.22e-05, T_loss: 1.39e+00, Time: 1.50
# It: 14400, KL_loss: -5.53e-03, Recon_loss: 3.04e-05, PDE_loss: 1.47e-04, T_loss: 1.39e+00, Time: 1.52
# It: 14500, KL_loss: -1.24e-02, Recon_loss: 3.06e-05, PDE_loss: 1.27e-04, T_loss: 1.39e+00, Time: 1.44
# It: 14600, KL_loss: -4.93e-03, Recon_loss: 5.60e-05, PDE_loss: 9.65e-05, T_loss: 1.39e+00, Time: 1.01
# It: 14700, KL_loss: -2.47e-03, Recon_loss: 3.94e-05, PDE_loss: 7.00e-05, T_loss: 1.39e+00, Time: 1.28
# It: 14800, KL_loss: -2.76e-04, Recon_loss: 1.25e-03, PDE_loss: 8.88e-05, T_loss: 1.39e+00, Time: 0.88
# It: 14900, KL_loss: 5.28e-03, Recon_loss: 4.86e-05, PDE_loss: 6.10e-05, T_loss: 1.39e+00, Time: 1.10
# It: 15000, KL_loss: 1.51e-02, Recon_loss: 3.06e-04, PDE_loss: 1.46e-04, T_loss: 1.38e+00, Time: 1.49
# It: 15100, KL_loss: -3.41e-04, Recon_loss: 4.95e-05, PDE_loss: 8.19e-05, T_loss: 1.39e+00, Time: 1.13
# It: 15200, KL_loss: -1.21e-02, Recon_loss: 4.68e-05, PDE_loss: 8.70e-05, T_loss: 1.38e+00, Time: 1.30
# It: 15300, KL_loss: -1.14e-02, Recon_loss: 3.13e-04, PDE_loss: 5.59e-05, T_loss: 1.39e+00, Time: 1.47
# It: 15400, KL_loss: -2.63e-04, Recon_loss: 1.07e-05, PDE_loss: 1.54e-04, T_loss: 1.39e+00, Time: 1.32
# It: 15500, KL_loss: 4.72e-03, Recon_loss: 1.08e-03, PDE_loss: 2.58e-04, T_loss: 1.39e+00, Time: 1.49
# It: 15600, KL_loss: 3.52e-03, Recon_loss: 4.53e-04, PDE_loss: 7.35e-05, T_loss: 1.39e+00, Time: 1.31
# It: 15700, KL_loss: -5.90e-03, Recon_loss: 2.34e-05, PDE_loss: 6.03e-05, T_loss: 1.38e+00, Time: 1.38
# It: 15800, KL_loss: -4.07e-04, Recon_loss: 1.82e-04, PDE_loss: 1.41e-04, T_loss: 1.38e+00, Time: 1.41
# It: 15900, KL_loss: 8.96e-03, Recon_loss: 1.47e-04, PDE_loss: 4.68e-05, T_loss: 1.38e+00, Time: 1.52
# It: 16000, KL_loss: -4.83e-03, Recon_loss: 1.49e-04, PDE_loss: 1.65e-04, T_loss: 1.39e+00, Time: 1.28
# It: 16100, KL_loss: -4.09e-03, Recon_loss: 1.90e-03, PDE_loss: 9.53e-05, T_loss: 1.38e+00, Time: 1.59
# It: 16200, KL_loss: 4.62e-03, Recon_loss: 1.60e-03, PDE_loss: 1.14e-04, T_loss: 1.39e+00, Time: 1.78
# It: 16300, KL_loss: 3.54e-03, Recon_loss: 1.24e-04, PDE_loss: 7.38e-05, T_loss: 1.38e+00, Time: 1.86
# It: 16400, KL_loss: -5.42e-03, Recon_loss: 1.02e-04, PDE_loss: 7.93e-05, T_loss: 1.39e+00, Time: 1.21
# It: 16500, KL_loss: 2.70e-03, Recon_loss: 1.51e-04, PDE_loss: 1.24e-04, T_loss: 1.39e+00, Time: 1.43
# It: 16600, KL_loss: 1.29e-02, Recon_loss: 4.43e-04, PDE_loss: 1.25e-04, T_loss: 1.38e+00, Time: 1.39
# It: 16700, KL_loss: 2.65e-03, Recon_loss: 2.26e-05, PDE_loss: 1.15e-04, T_loss: 1.39e+00, Time: 1.37
# It: 16800, KL_loss: -6.96e-03, Recon_loss: 8.22e-04, PDE_loss: 8.26e-05, T_loss: 1.38e+00, Time: 1.43
# It: 16900, KL_loss: 4.13e-03, Recon_loss: 1.52e-03, PDE_loss: 7.50e-05, T_loss: 1.39e+00, Time: 1.47
# It: 17000, KL_loss: 8.77e-03, Recon_loss: 3.85e-05, PDE_loss: 3.39e-04, T_loss: 1.38e+00, Time: 1.51
# It: 17100, KL_loss: 7.51e-03, Recon_loss: 6.75e-05, PDE_loss: 7.42e-05, T_loss: 1.38e+00, Time: 1.32
# It: 17200, KL_loss: -7.34e-03, Recon_loss: 9.03e-05, PDE_loss: 9.79e-05, T_loss: 1.39e+00, Time: 1.37
# It: 17300, KL_loss: -1.04e-02, Recon_loss: 1.49e-02, PDE_loss: 1.42e-04, T_loss: 1.39e+00, Time: 1.20
# It: 17400, KL_loss: 9.22e-03, Recon_loss: 3.25e-05, PDE_loss: 7.98e-05, T_loss: 1.38e+00, Time: 1.25
# It: 17500, KL_loss: 7.10e-03, Recon_loss: 1.61e-03, PDE_loss: 9.74e-05, T_loss: 1.38e+00, Time: 1.54
# It: 17600, KL_loss: -5.92e-03, Recon_loss: 7.69e-05, PDE_loss: 9.51e-05, T_loss: 1.38e+00, Time: 1.44
# It: 17700, KL_loss: 6.76e-03, Recon_loss: 5.30e-05, PDE_loss: 8.17e-05, T_loss: 1.38e+00, Time: 0.96
# It: 17800, KL_loss: -4.75e-03, Recon_loss: 1.18e-04, PDE_loss: 9.36e-05, T_loss: 1.39e+00, Time: 1.50
# It: 17900, KL_loss: -6.32e-03, Recon_loss: 1.04e-03, PDE_loss: 1.06e-04, T_loss: 1.38e+00, Time: 1.31
# It: 18000, KL_loss: 4.40e-03, Recon_loss: 2.04e-02, PDE_loss: 3.61e-04, T_loss: 1.38e+00, Time: 1.54
# It: 18100, KL_loss: 1.25e-02, Recon_loss: 5.74e-04, PDE_loss: 8.96e-05, T_loss: 1.38e+00, Time: 1.49
# It: 18200, KL_loss: -7.45e-04, Recon_loss: 1.75e-03, PDE_loss: 8.04e-05, T_loss: 1.38e+00, Time: 1.72
# It: 18300, KL_loss: -4.08e-03, Recon_loss: 9.21e-04, PDE_loss: 7.11e-05, T_loss: 1.38e+00, Time: 1.73
# It: 18400, KL_loss: 4.30e-03, Recon_loss: 1.00e-03, PDE_loss: 2.49e-04, T_loss: 1.39e+00, Time: 1.75
# It: 18500, KL_loss: 3.38e-03, Recon_loss: 4.52e-05, PDE_loss: 1.68e-04, T_loss: 1.39e+00, Time: 1.11
# It: 18600, KL_loss: -4.12e-03, Recon_loss: 3.06e-04, PDE_loss: 1.10e-04, T_loss: 1.38e+00, Time: 1.34
# It: 18700, KL_loss: 5.17e-03, Recon_loss: 1.19e-04, PDE_loss: 4.88e-05, T_loss: 1.38e+00, Time: 1.51
# It: 18800, KL_loss: 4.91e-03, Recon_loss: 2.69e-04, PDE_loss: 9.78e-05, T_loss: 1.39e+00, Time: 1.55
# It: 18900, KL_loss: 1.98e-03, Recon_loss: 8.07e-05, PDE_loss: 1.83e-04, T_loss: 1.39e+00, Time: 1.48
# It: 19000, KL_loss: -1.86e-03, Recon_loss: 2.92e-04, PDE_loss: 7.52e-05, T_loss: 1.39e+00, Time: 1.53
# It: 19100, KL_loss: 7.65e-03, Recon_loss: 4.02e-03, PDE_loss: 7.97e-05, T_loss: 1.38e+00, Time: 1.37
# It: 19200, KL_loss: -9.54e-03, Recon_loss: 8.32e-04, PDE_loss: 6.59e-05, T_loss: 1.39e+00, Time: 1.50
# It: 19300, KL_loss: 1.60e-02, Recon_loss: 2.02e-03, PDE_loss: 1.06e-04, T_loss: 1.38e+00, Time: 1.45
# It: 19400, KL_loss: -8.85e-04, Recon_loss: 7.98e-05, PDE_loss: 9.90e-05, T_loss: 1.38e+00, Time: 1.45
# It: 19500, KL_loss: -3.76e-03, Recon_loss: 4.00e-04, PDE_loss: 9.91e-05, T_loss: 1.38e+00, Time: 1.61
# It: 19600, KL_loss: 2.05e-03, Recon_loss: 1.02e-04, PDE_loss: 8.31e-05, T_loss: 1.39e+00, Time: 1.52
# It: 19700, KL_loss: 4.09e-03, Recon_loss: 2.64e-05, PDE_loss: 1.18e-04, T_loss: 1.38e+00, Time: 1.44
# It: 19800, KL_loss: -4.60e-03, Recon_loss: 5.31e-05, PDE_loss: 7.61e-05, T_loss: 1.39e+00, Time: 1.46
# It: 19900, KL_loss: 1.67e-03, Recon_loss: 3.90e-04, PDE_loss: 4.95e-05, T_loss: 1.38e+00, Time: 1.44
# It: 20000, KL_loss: 1.31e-03, Recon_loss: 3.01e-04, PDE_loss: 9.50e-05, T_loss: 1.39e+00, Time: 1.46
# It: 20100, KL_loss: 6.07e-03, Recon_loss: 9.06e-05, PDE_loss: 1.07e-04, T_loss: 1.38e+00, Time: 1.50
# It: 20200, KL_loss: 1.77e-04, Recon_loss: 9.69e-05, PDE_loss: 7.89e-05, T_loss: 1.39e+00, Time: 1.51
# It: 20300, KL_loss: 5.40e-03, Recon_loss: 1.67e-04, PDE_loss: 8.32e-05, T_loss: 1.39e+00, Time: 1.45
# It: 20400, KL_loss: -2.43e-04, Recon_loss: 1.97e-04, PDE_loss: 1.23e-04, T_loss: 1.38e+00, Time: 1.64
# It: 20500, KL_loss: -5.80e-03, Recon_loss: 4.03e-05, PDE_loss: 5.58e-05, T_loss: 1.38e+00, Time: 1.48
# It: 20600, KL_loss: 1.25e-02, Recon_loss: 6.36e-04, PDE_loss: 5.11e-05, T_loss: 1.38e+00, Time: 1.54
# It: 20700, KL_loss: -3.67e-03, Recon_loss: 1.55e-03, PDE_loss: 9.76e-05, T_loss: 1.38e+00, Time: 1.53
# It: 20800, KL_loss: 8.83e-03, Recon_loss: 1.17e-04, PDE_loss: 1.01e-04, T_loss: 1.38e+00, Time: 1.54
# It: 20900, KL_loss: 2.49e-03, Recon_loss: 1.55e-03, PDE_loss: 9.88e-05, T_loss: 1.38e+00, Time: 1.51
# It: 21000, KL_loss: 5.12e-03, Recon_loss: 5.38e-05, PDE_loss: 1.05e-04, T_loss: 1.38e+00, Time: 1.51
# It: 21100, KL_loss: -1.27e-03, Recon_loss: 7.51e-02, PDE_loss: 4.03e-04, T_loss: 1.39e+00, Time: 1.51
# It: 21200, KL_loss: -1.50e-03, Recon_loss: 7.40e-05, PDE_loss: 2.07e-04, T_loss: 1.38e+00, Time: 1.55
# It: 21300, KL_loss: 8.40e-03, Recon_loss: 4.10e-04, PDE_loss: 6.97e-05, T_loss: 1.38e+00, Time: 1.48
# It: 21400, KL_loss: 2.78e-03, Recon_loss: 6.42e-05, PDE_loss: 5.56e-05, T_loss: 1.38e+00, Time: 1.39
# It: 21500, KL_loss: 3.97e-03, Recon_loss: 5.64e-05, PDE_loss: 2.34e-04, T_loss: 1.38e+00, Time: 1.37
# It: 21600, KL_loss: 2.15e-03, Recon_loss: 3.75e-04, PDE_loss: 8.06e-05, T_loss: 1.38e+00, Time: 1.51
# It: 21700, KL_loss: -1.78e-03, Recon_loss: 2.62e-05, PDE_loss: 6.59e-05, T_loss: 1.39e+00, Time: 1.50
# It: 21800, KL_loss: -2.43e-04, Recon_loss: 6.17e-05, PDE_loss: 7.08e-05, T_loss: 1.38e+00, Time: 1.70
# It: 21900, KL_loss: 2.78e-03, Recon_loss: 1.05e-03, PDE_loss: 5.97e-05, T_loss: 1.39e+00, Time: 1.46
# It: 22000, KL_loss: -7.28e-03, Recon_loss: 4.93e-05, PDE_loss: 9.00e-05, T_loss: 1.38e+00, Time: 1.61
# It: 22100, KL_loss: 1.28e-02, Recon_loss: 7.04e-04, PDE_loss: 1.34e-04, T_loss: 1.38e+00, Time: 1.25
# It: 22200, KL_loss: -8.96e-03, Recon_loss: 1.05e-03, PDE_loss: 1.12e-04, T_loss: 1.38e+00, Time: 1.31
# It: 22300, KL_loss: 7.90e-03, Recon_loss: 2.34e-03, PDE_loss: 1.71e-04, T_loss: 1.38e+00, Time: 1.30
# It: 22400, KL_loss: -6.68e-04, Recon_loss: 1.29e-03, PDE_loss: 1.08e-04, T_loss: 1.38e+00, Time: 0.88
# It: 22500, KL_loss: -2.16e-03, Recon_loss: 6.99e-03, PDE_loss: 2.39e-04, T_loss: 1.38e+00, Time: 0.93
# It: 22600, KL_loss: 4.75e-03, Recon_loss: 5.80e-05, PDE_loss: 5.36e-05, T_loss: 1.38e+00, Time: 0.98
# It: 22700, KL_loss: 1.62e-03, Recon_loss: 1.29e-04, PDE_loss: 6.48e-05, T_loss: 1.38e+00, Time: 1.38
# It: 22800, KL_loss: 1.06e-03, Recon_loss: 3.21e-05, PDE_loss: 6.97e-05, T_loss: 1.38e+00, Time: 1.34
# It: 22900, KL_loss: 7.05e-03, Recon_loss: 4.05e-05, PDE_loss: 1.05e-04, T_loss: 1.38e+00, Time: 1.32
# It: 23000, KL_loss: 6.99e-04, Recon_loss: 5.01e-04, PDE_loss: 7.46e-05, T_loss: 1.38e+00, Time: 1.38
# It: 23100, KL_loss: -8.27e-04, Recon_loss: 9.64e-05, PDE_loss: 1.72e-04, T_loss: 1.38e+00, Time: 1.37
# It: 23200, KL_loss: 2.53e-03, Recon_loss: 1.04e-03, PDE_loss: 1.06e-04, T_loss: 1.38e+00, Time: 1.32
# It: 23300, KL_loss: -3.28e-03, Recon_loss: 7.71e-05, PDE_loss: 6.38e-05, T_loss: 1.38e+00, Time: 0.87
# It: 23400, KL_loss: 7.57e-03, Recon_loss: 3.88e-05, PDE_loss: 1.09e-04, T_loss: 1.38e+00, Time: 1.41
# It: 23500, KL_loss: -2.97e-03, Recon_loss: 3.20e-05, PDE_loss: 7.87e-05, T_loss: 1.38e+00, Time: 1.32
# It: 23600, KL_loss: -2.07e-03, Recon_loss: 5.43e-04, PDE_loss: 1.39e-04, T_loss: 1.38e+00, Time: 1.41
# It: 23700, KL_loss: 1.14e-02, Recon_loss: 1.09e-04, PDE_loss: 6.86e-05, T_loss: 1.38e+00, Time: 1.31
# It: 23800, KL_loss: -1.75e-03, Recon_loss: 9.22e-05, PDE_loss: 7.89e-05, T_loss: 1.38e+00, Time: 1.12
# It: 23900, KL_loss: 2.63e-03, Recon_loss: 4.64e-04, PDE_loss: 6.63e-05, T_loss: 1.38e+00, Time: 1.38
# It: 24000, KL_loss: 5.72e-03, Recon_loss: 2.08e-04, PDE_loss: 1.07e-04, T_loss: 1.38e+00, Time: 1.44
# It: 24100, KL_loss: -9.97e-03, Recon_loss: 1.19e-04, PDE_loss: 1.62e-04, T_loss: 1.38e+00, Time: 1.50
# It: 24200, KL_loss: 5.57e-03, Recon_loss: 6.11e-04, PDE_loss: 1.47e-04, T_loss: 1.38e+00, Time: 1.42
# It: 24300, KL_loss: -3.75e-03, Recon_loss: 2.93e-04, PDE_loss: 6.24e-05, T_loss: 1.38e+00, Time: 1.46
# It: 24400, KL_loss: -2.78e-03, Recon_loss: 9.27e-05, PDE_loss: 5.75e-05, T_loss: 1.38e+00, Time: 1.52
# It: 24500, KL_loss: 2.51e-03, Recon_loss: 3.98e-05, PDE_loss: 5.61e-05, T_loss: 1.38e+00, Time: 1.36
# It: 24600, KL_loss: 1.32e-03, Recon_loss: 1.15e-04, PDE_loss: 7.32e-05, T_loss: 1.38e+00, Time: 1.38
# It: 24700, KL_loss: -1.37e-03, Recon_loss: 4.37e-03, PDE_loss: 1.01e-04, T_loss: 1.38e+00, Time: 1.51
# It: 24800, KL_loss: 1.46e-02, Recon_loss: 2.29e-04, PDE_loss: 7.35e-05, T_loss: 1.38e+00, Time: 1.55
# It: 24900, KL_loss: -4.16e-03, Recon_loss: 2.40e-03, PDE_loss: 6.67e-04, T_loss: 1.38e+00, Time: 1.90
# It: 25000, KL_loss: 6.63e-03, Recon_loss: 1.14e-03, PDE_loss: 6.61e-05, T_loss: 1.38e+00, Time: 1.59
# It: 25100, KL_loss: 7.93e-03, Recon_loss: 3.51e-05, PDE_loss: 6.00e-05, T_loss: 1.38e+00, Time: 1.43
# It: 25200, KL_loss: 3.89e-03, Recon_loss: 1.70e-04, PDE_loss: 7.74e-05, T_loss: 1.38e+00, Time: 1.37
# It: 25300, KL_loss: 5.00e-04, Recon_loss: 1.11e-04, PDE_loss: 3.10e-04, T_loss: 1.38e+00, Time: 1.30
# It: 25400, KL_loss: 5.09e-03, Recon_loss: 3.11e-03, PDE_loss: 8.60e-05, T_loss: 1.38e+00, Time: 1.40
# It: 25500, KL_loss: 9.43e-03, Recon_loss: 5.35e-03, PDE_loss: 4.72e-05, T_loss: 1.38e+00, Time: 1.42
# It: 25600, KL_loss: -5.13e-04, Recon_loss: 1.19e-03, PDE_loss: 8.96e-05, T_loss: 1.38e+00, Time: 1.75
# It: 25700, KL_loss: 8.24e-04, Recon_loss: 1.12e-03, PDE_loss: 7.27e-05, T_loss: 1.38e+00, Time: 1.36
# It: 25800, KL_loss: 4.86e-03, Recon_loss: 2.89e-04, PDE_loss: 9.64e-05, T_loss: 1.38e+00, Time: 1.38
# It: 25900, KL_loss: 8.07e-03, Recon_loss: 8.73e-05, PDE_loss: 4.49e-05, T_loss: 1.38e+00, Time: 1.66
# It: 26000, KL_loss: -1.13e-03, Recon_loss: 7.51e-05, PDE_loss: 9.44e-05, T_loss: 1.38e+00, Time: 1.30
# It: 26100, KL_loss: 6.29e-03, Recon_loss: 4.09e-04, PDE_loss: 1.14e-04, T_loss: 1.38e+00, Time: 1.55
# It: 26200, KL_loss: 6.28e-03, Recon_loss: 6.62e-05, PDE_loss: 1.09e-04, T_loss: 1.38e+00, Time: 1.63
# It: 26300, KL_loss: 6.15e-03, Recon_loss: 8.14e-05, PDE_loss: 1.26e-04, T_loss: 1.38e+00, Time: 1.43
# It: 26400, KL_loss: 9.92e-03, Recon_loss: 1.46e-04, PDE_loss: 1.12e-04, T_loss: 1.38e+00, Time: 1.64
# It: 26500, KL_loss: 2.96e-04, Recon_loss: 1.24e-04, PDE_loss: 1.34e-04, T_loss: 1.38e+00, Time: 1.32
# It: 26600, KL_loss: 1.69e-02, Recon_loss: 4.91e-03, PDE_loss: 1.80e-04, T_loss: 1.38e+00, Time: 1.36
# It: 26700, KL_loss: 2.69e-03, Recon_loss: 1.53e-01, PDE_loss: 3.82e-04, T_loss: 1.38e+00, Time: 1.65
# It: 26800, KL_loss: -4.91e-04, Recon_loss: 1.57e-04, PDE_loss: 1.54e-04, T_loss: 1.38e+00, Time: 1.53
# It: 26900, KL_loss: -9.26e-04, Recon_loss: 6.44e-03, PDE_loss: 1.57e-04, T_loss: 1.38e+00, Time: 1.40
# It: 27000, KL_loss: -2.31e-03, Recon_loss: 1.34e-04, PDE_loss: 1.09e-04, T_loss: 1.38e+00, Time: 1.23
# It: 27100, KL_loss: -1.75e-03, Recon_loss: 1.43e-04, PDE_loss: 7.60e-05, T_loss: 1.38e+00, Time: 1.59
# It: 27200, KL_loss: 3.89e-03, Recon_loss: 2.58e-04, PDE_loss: 8.51e-05, T_loss: 1.38e+00, Time: 1.33
# It: 27300, KL_loss: 3.54e-03, Recon_loss: 9.15e-03, PDE_loss: 1.28e-04, T_loss: 1.38e+00, Time: 1.19
# It: 27400, KL_loss: 1.46e-03, Recon_loss: 4.63e-04, PDE_loss: 6.58e-05, T_loss: 1.38e+00, Time: 1.24
# It: 27500, KL_loss: -1.54e-03, Recon_loss: 1.21e-04, PDE_loss: 7.15e-05, T_loss: 1.38e+00, Time: 1.16
# It: 27600, KL_loss: 5.88e-03, Recon_loss: 1.09e-04, PDE_loss: 9.15e-05, T_loss: 1.38e+00, Time: 1.25
# It: 27700, KL_loss: 1.23e-03, Recon_loss: 1.45e-04, PDE_loss: 1.10e-04, T_loss: 1.38e+00, Time: 1.45
# It: 27800, KL_loss: -1.70e-03, Recon_loss: 4.19e-03, PDE_loss: 9.43e-05, T_loss: 1.38e+00, Time: 1.50
# It: 27900, KL_loss: -4.27e-03, Recon_loss: 3.87e-03, PDE_loss: 1.83e-04, T_loss: 1.38e+00, Time: 1.47
# It: 28000, KL_loss: 6.17e-03, Recon_loss: 1.02e-04, PDE_loss: 1.53e-04, T_loss: 1.38e+00, Time: 1.52
# It: 28100, KL_loss: -1.75e-03, Recon_loss: 2.19e-04, PDE_loss: 8.81e-05, T_loss: 1.38e+00, Time: 1.37
# It: 28200, KL_loss: -2.13e-03, Recon_loss: 4.26e-05, PDE_loss: 1.32e-04, T_loss: 1.38e+00, Time: 1.44
# It: 28300, KL_loss: 6.81e-03, Recon_loss: 1.88e-04, PDE_loss: 1.43e-04, T_loss: 1.38e+00, Time: 1.45
# It: 28400, KL_loss: 5.25e-03, Recon_loss: 4.35e-05, PDE_loss: 8.81e-05, T_loss: 1.38e+00, Time: 1.51
# It: 28500, KL_loss: -1.35e-04, Recon_loss: 1.56e-04, PDE_loss: 1.57e-04, T_loss: 1.38e+00, Time: 1.44
# It: 28600, KL_loss: -4.37e-03, Recon_loss: 1.44e-04, PDE_loss: 8.53e-05, T_loss: 1.38e+00, Time: 1.67
# It: 28700, KL_loss: 5.42e-03, Recon_loss: 1.37e-04, PDE_loss: 9.50e-05, T_loss: 1.38e+00, Time: 1.65
# It: 28800, KL_loss: -6.51e-04, Recon_loss: 1.88e-02, PDE_loss: 2.31e-04, T_loss: 1.38e+00, Time: 1.61
# It: 28900, KL_loss: 1.34e-03, Recon_loss: 4.02e-03, PDE_loss: 9.99e-05, T_loss: 1.38e+00, Time: 1.64
# It: 29000, KL_loss: 7.10e-03, Recon_loss: 1.62e-02, PDE_loss: 1.22e-04, T_loss: 1.38e+00, Time: 1.57
# It: 29100, KL_loss: 1.41e-02, Recon_loss: 8.66e-04, PDE_loss: 1.12e-04, T_loss: 1.38e+00, Time: 1.51
# It: 29200, KL_loss: 4.79e-03, Recon_loss: 2.27e-04, PDE_loss: 5.24e-05, T_loss: 1.38e+00, Time: 1.73
# It: 29300, KL_loss: 5.98e-04, Recon_loss: 3.22e-04, PDE_loss: 6.32e-05, T_loss: 1.38e+00, Time: 1.53
# It: 29400, KL_loss: 2.83e-03, Recon_loss: 2.84e-01, PDE_loss: 8.13e-04, T_loss: 1.38e+00, Time: 1.57
# It: 29500, KL_loss: 4.82e-04, Recon_loss: 1.86e-04, PDE_loss: 5.41e-05, T_loss: 1.38e+00, Time: 1.75
# It: 29600, KL_loss: 8.09e-04, Recon_loss: 1.72e-04, PDE_loss: 1.05e-04, T_loss: 1.38e+00, Time: 1.41
# It: 29700, KL_loss: 5.99e-03, Recon_loss: 1.80e-04, PDE_loss: 9.15e-05, T_loss: 1.38e+00, Time: 1.45
# It: 29800, KL_loss: 8.14e-04, Recon_loss: 1.84e-04, PDE_loss: 1.37e-04, T_loss: 1.38e+00, Time: 1.50
# It: 29900, KL_loss: 7.83e-03, Recon_loss: 2.63e-04, PDE_loss: 8.91e-05, T_loss: 1.38e+00, Time: 1.44

# %%
# Prediction

# Make prediciton at randomly chosen points X_ff (black lines are generated samples, red stars are predicted mean)
plt.figure(1)
N_samples = 2000
samples_mean = np.zeros((X_ref.shape[0], N_samples))
for i in range(0, N_samples):
    samples_mean[:,i:i+1] = model.generate_sample(X_ref)

# Compute the mean and the variance of the prediction at randomly selected points in the domain
mu_pred = np.mean(samples_mean, axis = 1)    
Sigma_pred = np.var(samples_mean, axis = 1)

# %%
# Plot the prediction with the uncertainty versus the reference solution

ax = plt.figure(2,figsize=(7,5))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(X_u, Y_u, 'kx', markersize = 4, label = "Data points")
lower = mu_pred - 2.0*np.sqrt(Sigma_pred)
upper = mu_pred + 2.0*np.sqrt(Sigma_pred)
plt.fill_between(X_ref.flatten(), lower.flatten(), upper.flatten(), 
                  facecolor='orange', alpha=0.5, label="Two std band")
plt.plot(X_ref,Y_ref,'b-', label = "Exact", linewidth=2)
plt.plot(X_ref, mu_pred, 'r--', label = "Prediction", linewidth=2)
plt.xlabel('X (m)',fontsize=14)
plt.ylabel('Defelection (x $10^{-4}$ m)',fontsize=14)
plt.legend(loc='lower left', frameon=True, prop={'size': 13})
# Save the figure as a PNG file
plt.savefig('UQ_with_GAN5.png', dpi=300)
plt.show()

# %%
# Compute the prediction relative error 

mu_pred = mu_pred[:,None]
error_u = np.linalg.norm(Y_ref-mu_pred,2)/np.linalg.norm(Y_ref,2)
print('Error u: %e' % (error_u))
# Out:
# Error u: 7.912620e-03
